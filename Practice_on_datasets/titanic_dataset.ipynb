# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df[df.dtypes[df.dtypes == 'object'].index][df['Sex'] == 'female'][df['Name'].str.contains('Martha')][df['Ticket'].str.endswith('505')]

## a new square bracket is added for each subsequent filter/condition
# Out:
# /tmp/ipykernel_19405/3619434517.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.dtypes[df.dtypes == 'object'].index][df['Sex'] == 'female'][df['Name'].str.contains('Martha')][df['Ticket'].str.endswith('505')]
#                                        Name     Sex  Ticket Cabin Embarked
# 166  Chibnall, Mrs. (Edith Martha Bowerman)  female  113505   E33        S

# %%
import numpy as np

# %%
df['Age'].isnull() == True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
age_null = np.where(df['Age'].isnull() == True)

# %%
type(age_null)
# Out:
# tuple

# %%
age_null
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
df.iloc[age_null]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
## find persons with highest fare

# %%
highest_fare = np.where(df['Fare'] == max(df['Fare']))

# %%
highest_fare
# Out:
# (array([258, 679, 737]),)

# %%
df.iloc[highest_fare]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
df[['Name']][df['Fare'] == max(df['Fare'])]
# Out:
#                                    Name
# 258                    Ward, Miss. Anna
# 679  Cardeza, Mr. Thomas Drake Martinez
# 737              Lesurer, Mr. Gustave J

# %%
## age of person(s) whose cabin is NaN
cabin_null = np.where(df['Cabin'].isnull() == True)
df.iloc[cabin_null]['Name']
# Out:
# 0                       Braund, Mr. Owen Harris
# 2                        Heikkinen, Miss. Laina
# 4                      Allen, Mr. William Henry
# 5                              Moran, Mr. James
# 7                Palsson, Master. Gosta Leonard
#                          ...
# 884                      Sutehall, Mr. Henry Jr
# 885        Rice, Mrs. William (Margaret Norton)
# 886                       Montvila, Rev. Juozas
# 888    Johnston, Miss. Catherine Helen "Carrie"
# 890                         Dooley, Mr. Patrick
# Name: Name, Length: 687, dtype: object

# %%
## survived male passengers
df[['Name','Sex','Survived']][df['Sex'] == 'male'][df['Survived'] == 1]
# Out:
# /tmp/ipykernel_19405/2459022302.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[['Name','Sex','Survived']][df['Sex'] == 'male'][df['Survived'] == 1]
#                                 Name   Sex  Survived
# 17      Williams, Mr. Charles Eugene  male         1
# 21             Beesley, Mr. Lawrence  male         1
# 23      Sloper, Mr. William Thompson  male         1
# 36                  Mamee, Mr. Hanna  male         1
# 55                 Woolner, Mr. Hugh  male         1
# ..                               ...   ...       ...
# 838                  Chip, Mr. Chang  male         1
# 839             Marechal, Mr. Pierre  male         1
# 857           Daly, Mr. Peter Denis   male         1
# 869  Johnson, Master. Harold Theodor  male         1
# 889            Behr, Mr. Karl Howell  male         1
#
# [109 rows x 3 columns]

# %%
df.iloc[np.where(df['Sex'] == 'male')][df['Survived'] == 1]
# Out:
# /tmp/ipykernel_19405/2091242942.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.iloc[np.where(df['Sex'] == 'male')][df['Survived'] == 1]
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# ...

# %%
df[['Name','Survived','Sex']][(df['Survived'] == 1) & (df['Sex'] == 'male')]
# Out:
#                                 Name  Survived   Sex
# 17      Williams, Mr. Charles Eugene         1  male
# 21             Beesley, Mr. Lawrence         1  male
# 23      Sloper, Mr. William Thompson         1  male
# 36                  Mamee, Mr. Hanna         1  male
# 55                 Woolner, Mr. Hugh         1  male
# ..                               ...       ...   ...
# 838                  Chip, Mr. Chang         1  male
# 839             Marechal, Mr. Pierre         1  male
# 857           Daly, Mr. Peter Denis          1  male
# 869  Johnson, Master. Harold Theodor         1  male
# 889            Behr, Mr. Karl Howell         1  male
#
# [109 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
df['Age'].hist(bins=50, figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
plt.show()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
