# %% [markdown]
# https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv

# %%
import pandas as pd

# %%
df = pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv')

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df = df.rename(columns = {'item_price':'str_type_price'})

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# str_type_price        object
# dtype: object

# %%
df['item_price'] = df['str_type_price'].str.replace('$', "").astype(float)
# Out:
# /tmp/ipykernel_86988/613537759.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['item_price'] = df['str_type_price'].str.replace('$', "").astype(float)

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description str_type_price  \
# 0                                                   NaN         $2.39
# ...

# %%
df['total_cost'] = df['item_price']*df['quantity']

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description str_type_price  \
# 0                                                   NaN         $2.39
# ...

# %%
df[['item_name', 'total_cost', 'choice_description', 'quantity']][df['total_cost']>50][df['quantity']>1]
# Out:
# /tmp/ipykernel_86988/245677906.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[['item_name', 'total_cost', 'choice_description', 'quantity']][df['total_cost']>50][df['quantity']>1]
#                          item_name  total_cost  \
# 409                   Chicken Bowl       98.82
# 445                           Bowl       66.60
# 1254               Chicken Burrito      140.00
# 1255                 Steak Burrito       83.25
# 1514                  Chicken Bowl       78.75
# 3334                    Steak Bowl       78.21
# 3480                 Carnitas Bowl      105.75
# 3598  Chips and Fresh Tomato Salsa      663.75
# 3599                 Bottled Water       73.50
# 3601                Veggie Burrito      101.25
# 3602               Chicken Burrito      140.00
# 3603                 Steak Burrito       83.25
# 3634               Chicken Burrito       78.75
# 3636               Chicken Burrito       78.75
# ...

# %%
type(df['choice_description'][409])
# Out:
# str

# %%
import numpy as np

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description str_type_price  \
# 0                                                   NaN         $2.39
# ...
