# %%
import requests
import pandas as pd

# %%
import numpy as np

# %%
res = requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
res
# Out:
# <Response [200]>

# %%
js = res.json()

# %%
js # data set is available in the form of list
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47983',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47983/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47983/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47983/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47983',
#   'id': 1330040995,
#   'node_id': 'I_kwDOAA0YD85PRtCj',
#   'number': 47983,
#   'title': 'BUG: Dataframe.to_xml() fails with control characters',
#   'user': {'login': 'CarlosHartmann',
#    'id': 65766894,
#    'node_id': 'MDQ6VXNlcjY1NzY2ODk0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65766894?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CarlosHartmann',
#    'html_url': 'https://github.com/CarlosHartmann',
# ...

# %%
js[0]['user']
# Out:
# {'login': 'CarlosHartmann',
#  'id': 65766894,
#  'node_id': 'MDQ6VXNlcjY1NzY2ODk0',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/65766894?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/CarlosHartmann',
#  'html_url': 'https://github.com/CarlosHartmann',
#  'followers_url': 'https://api.github.com/users/CarlosHartmann/followers',
#  'following_url': 'https://api.github.com/users/CarlosHartmann/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/CarlosHartmann/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/CarlosHartmann/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/CarlosHartmann/subscriptions',
#  'organizations_url': 'https://api.github.com/users/CarlosHartmann/orgs',
#  'repos_url': 'https://api.github.com/users/CarlosHartmann/repos',
#  'events_url': 'https://api.github.com/users/CarlosHartmann/events{/privacy}',
# ...

# %%
df = pd.DataFrame(js)

# %%
df.to_csv('json_dump.csv')

# %%
users_list = []

# %%
for i in range(len(js)):
    users_list.append(js[i]['user'])

# %%
users_df = pd.DataFrame(users_list)

# %%
users_df['login']
# Out:
# 0      CarlosHartmann
# 1              devmcp
# 2        BarkotBeyene
# 3               phofl
# 4     simonjayhawkins
# 5        jbrockmendel
# 6              DRudel
# 7          rhshadrach
# 8               phofl
# 9               phofl
# 10           attack68
# 11       MarcoGorelli
# 12            bollard
# 13       MarcoGorelli
# 14       MarcoGorelli
# 15     datapythonista
# 16           Th3nn3ss
# 17       JeffersonQin
# 18            Mehgarg
# 19            jreback
# 20            colomb8
# 21              phofl
# 22       MarcoGorelli
# 23          tpackard1
# 24       SomtochiUmeh
# 25            nsarang
# 26      galipremsagar
# 27         henrykwong
# 28             btodac
# 29           shourya5
# Name: login, dtype: object

# %%
file = pd.read_csv('json_dump.csv')

# %%
pickle_file = file.to_pickle('picke_file')

# %%
h5_data = pd.HDFStore('test.h5')
# Out:
# ---------------------------------------------------------------------------
# HDF5ExtError                              Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 h5_data = pd.HDFStore('test.h5')
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/pytables.py:591, in HDFStore.__init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     589 self._fletcher32 = fletcher32
#     590 self._filters = None
# --> 591 self.open(mode=mode, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/pytables.py:740, in HDFStore.open(self, mode, **kwargs)
#     734     msg = (
#     735         "Cannot open HDF5 file, which is already opened, "
#     736         "even in read-only mode."
#     737     )
#     738     raise ValueError(msg)
# --> 740 self._handle = tables.open_file(self._path, self._mode, **kwargs)
#
# ...

# %%
h5_data.put('obj1', file, format='table')

# %%
titanic_df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
(titanic_df[titanic_df.dtypes[titanic_df.dtypes == 'float64'].index]).describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
titanic_df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic_df['Name'][8:20]
# Out:
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# 15                     Hewlett, Mrs. (Mary D Kingcome)
# 16                                 Rice, Master. Eugene
# 17                         Williams, Mr. Charles Eugene
# 18    Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19                              Masselmani, Mrs. Fatima
# Name: Name, dtype: object

# %%
sorted([titanic_df[['Name','Ticket']][5:120]])
# Out:
# [                                                  Name             Ticket
#  5                                     Moran, Mr. James             330877
#  6                              McCarthy, Mr. Timothy J              17463
#  7                       Palsson, Master. Gosta Leonard             349909
#  8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             347742
#  9                  Nasser, Mrs. Nicholas (Adele Achem)             237736
#  ..                                                 ...                ...
#  115                              Pekoniemi, Mr. Edvard  STON/O 2. 3101294
#  116                               Connors, Mr. Patrick             370369
#  117                    Turpin, Mr. William John Robert              11668
#  118                           Baxter, Mr. Quigg Edmond           PC 17558
#  119                  Andersson, Miss. Ellis Anna Maria             347082
#
#  [115 rows x 2 columns]]

# %%
titanic_df['new_col'] = 'new'

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df['new_col'] = titanic_df['PassengerId']
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
pd.Categorical(titanic_df['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
pd.Categorical(titanic_df['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
(titanic_df['Cabin'].unique())
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
titanic_df[['Cabin', 'Name']][titanic_df['Cabin'] == 'C123']
# Out:
#     Cabin                                          Name
# 3    C123  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 137  C123                   Futrelle, Mr. Jacques Heath

# %%
## get all records where survived value is NaN

survived_null = titanic_df[['Survived']][titanic_df['Cabin'].isnull() == True]

survived_null.index
# Out:
# Int64Index([  0,   2,   4,   5,   7,   8,   9,  12,  13,  14,
#             ...
#             878, 880, 881, 882, 883, 884, 885, 886, 888, 890],
#            dtype='int64', length=687)

# %%
titanic_df.iloc[survived_null.index]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
## get person name paid the highest fare

titanic_df[['Name', 'Fare']][titanic_df['Fare'] == max(titanic_df['Fare']) ]
# Out:
#                                    Name      Fare
# 258                    Ward, Miss. Anna  512.3292
# 679  Cardeza, Mr. Thomas Drake Martinez  512.3292
# 737              Lesurer, Mr. Gustave J  512.3292

# %%
titanic_df['DollarFare'] =  '$' + str(titanic_df['Fare'][titanic_df['Fare']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 titanic_df['DollarFare'] =  '$' + str(titanic_df['Fare'][titanic_df['Fare']])
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:984, in Series.__getitem__(self, key)
#     981     key = np.asarray(key, dtype=bool)
#     982     return self._get_values(key)
# --> 984 return self._get_with(key)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:1024, in Series._get_with(self, key)
#    1021         return self.iloc[key]
#    1023 # handle the dup indexing case GH#4246
# -> 1024 return self.loc[key]
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# ...

# %%
titanic_df.astype({'Fare':object})

# %%
titanic_df['new_col'] = '$' +  titanic_df['Fare'].astype(str)

# %%
titanic_df

# %%
titanic_df['new_col'] =  titanic_df['new_col'].str.replace('$', "").astype(float)

# %%
titanic_df.dtypes

# %%
import numpy as np

# %%
df = pd.DataFrame(np.random.randint(0, 255, (4,5)), index=['a','b','c','d'], columns=['x','y','z','u','v'])

# %%
df
# Out:
#      x    y    z    u    v
# a   99  133  127  233  228
# b  212  105   20  116  233
# c  119  123  252  181  213
# d   33   30  197  227  123

# %%
df.loc[['c','d']][['z','u']]
# Out:
#      z    u
# c  252  181
# d  197  227

# %%
## OR
df.loc[['c','d'],['z','u']]
# Out:
#      z    u
# c  252  181
# d  197  227

# %%
df
# Out:
#      x    y    z    u    v
# a   99  133  127  233  228
# b  212  105   20  116  233
# c  119  123  252  181  213
# d   33   30  197  227  123

# %%
df.drop('a')
# Out:
#      x    y    z    u    v
# b  212  105   20  116  233
# c  119  123  252  181  213
# d   33   30  197  227  123

# %%
df.drop('x', axis=1, inplace=True) #setting inplace=True permanently drops the column

# %%
df
# Out:
#      y    z    u    v
# a  133  127  233  228
# b  105   20  116  233
# c  123  252  181  213
# d   30  197  227  123

# %%
df
# Out:
#      y    z    u    v
# a  133  127  233  228
# b  105   20  116  233
# c  123  252  181  213
# d   30  197  227  123

# %%
np.random.seed(23)

# %%
df = pd.DataFrame(np.random.randn(4,5), index=['a','b','c','d'], columns=['x','y','z','u','v'])

# %%
df
# Out:
#           x         y         z         u         v
# a  0.666988  0.025813 -0.777619  0.948634  0.701672
# b -1.051082 -0.367548 -1.137460 -1.322148  1.772258
# c -0.347459  0.670140  0.322272  0.060343 -1.043450
# d -1.009942  0.441736  1.128877 -1.838068 -0.938769

# %%
## task : extract all negative values from the dataframe into a list

# %%
ans = []
for i in df:
    for j in df[i]:
        if j < 0:
            ans.append((j, i, df[i][df[i]<0]))
            
for i in ans:
    print(i)
# Out:
# (-1.0510815639071178, 'x', b   -1.051082
# c   -0.347459
# d   -1.009942
# Name: x, dtype: float64)
# (-0.34745899102186334, 'x', b   -1.051082
# c   -0.347459
# d   -1.009942
# Name: x, dtype: float64)
# (-1.0099418765878465, 'x', b   -1.051082
# c   -0.347459
# d   -1.009942
# Name: x, dtype: float64)
# (-0.3675481161171661, 'y', b   -0.367548
# Name: y, dtype: float64)
# (-0.7776194131918178, 'z', a   -0.777619
# b   -1.137460
# Name: z, dtype: float64)
# (-1.1374596907250272, 'z', a   -0.777619
# b   -1.137460
# Name: z, dtype: float64)
# (-1.3221475225908594, 'u', b   -1.322148
# d   -1.838068
# Name: u, dtype: float64)
# (-1.8380677677579502, 'u', b   -1.322148
# d   -1.838068
# Name: u, dtype: float64)
# (-1.0434500017467254, 'v', c   -1.043450
# d   -0.938769
# Name: v, dtype: float64)
# (-0.9387686311201282, 'v', c   -1.043450
# d   -0.938769
# Name: v, dtype: float64)

# %%
##aliter
ans = df.values[df.values < 0]
ans
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
for i in df.columns:
    for j in df.index:
        if df.loc[j,i] in ans:
            
            print(j,i, df[i][j])
# Out:
# b x -1.0510815639071178
# c x -0.34745899102186334
# d x -1.0099418765878465
# b y -0.3675481161171661
# a z -0.7776194131918178
# b z -1.1374596907250272
# b u -1.3221475225908594
# d u -1.8380677677579502
# c v -1.0434500017467254
# d v -0.9387686311201282

# %%
for i in df.columns:
    for j in df.index:
        if df[i][j] < 0:
            print(i, j, df[i][j])
# Out:
# x b -1.0510815639071178
# x c -0.34745899102186334
# x d -1.0099418765878465
# y b -0.3675481161171661
# z a -0.7776194131918178
# z b -1.1374596907250272
# u b -1.3221475225908594
# u d -1.8380677677579502
# v c -1.0434500017467254
# v d -0.9387686311201282

# %%
df.loc['a','x']
# Out:
# 0.6669880563534684

# %%
d1 = {
    'key1': [1,2,3,4,np.nan],
    'key2': ['sudh', 'kumar', 4,5,6],
    'key3': [np.nan,np.nan,np.nan,3,8]
}

# %%
df = pd.DataFrame(d1)

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna()
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.fillna(value=df['key1'].mean())
# Out:
#    key1   key2  key3
# 0   1.0   sudh   2.5
# 1   2.0  kumar   2.5
# 2   3.0      4   2.5
# 3   4.0      5   3.0
# 4   2.5      6   8.0

# %%
df
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df['key3'].fillna(value = df['key3'].mean(), inplace=True)

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   5.5
# 1   2.0  kumar   5.5
# 2   3.0      4   5.5
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
d2 = {
    'name':['harshal', 'abhishek', 'riyan', 'parag'],
    'mail_id':['harshal@gmail.com', 'abhi@yahoo.com', 'parag@gmail.com', 'parag@gmail.com'],
    'salary':[500,100, 1000, 200]
}

# %%
df1 = pd.DataFrame(d2)

# %%
df1
# Out:
#        name            mail_id  salary
# 0   harshal  harshal@gmail.com     500
# 1  abhishek     abhi@yahoo.com     100
# 2     riyan    parag@gmail.com    1000
# 3     parag    parag@gmail.com     200

# %%
df1.groupby('mail_id').describe()
# Out:
#                   salary                                                 \
#                    count   mean         std    min    25%    50%    75%
# mail_id
# abhi@yahoo.com       1.0  100.0         NaN  100.0  100.0  100.0  100.0
# harshal@gmail.com    1.0  500.0         NaN  500.0  500.0  500.0  500.0
# parag@gmail.com      2.0  600.0  565.685425  200.0  400.0  600.0  800.0
#
#
#                       max
# mail_id
# abhi@yahoo.com      100.0
# harshal@gmail.com   500.0
# parag@gmail.com    1000.0

# %%
df1.groupby('mail_id').describe().loc['harshal@gmail.com']
# Out:
# salary  count      1.0
#         mean     500.0
#         std        NaN
#         min      500.0
#         25%      500.0
#         50%      500.0
#         75%      500.0
#         max      500.0
# Name: harshal@gmail.com, dtype: float64

# %%
df1.groupby('mail_id').describe().loc['harshal@gmail.com']['salary']
# Out:
# 500.0

# %%
df1.groupby('mail_id').describe().loc['harshal@gmail.com']['salary']['mean']
# Out:
# 500.0

# %%
df1.groupby('mail_id').describe().transpose()
# Out:
# mail_id       abhi@yahoo.com  harshal@gmail.com  parag@gmail.com
# salary count             1.0                1.0         2.000000
#        mean            100.0              500.0       600.000000
#        std               NaN                NaN       565.685425
#        min             100.0              500.0       200.000000
#        25%             100.0              500.0       400.000000
#        50%             100.0              500.0       600.000000
#        75%             100.0              500.0       800.000000
#        max             100.0              500.0      1000.000000

# %%
df1.groupby('mail_id').describe().T
# Out:
# mail_id       abhi@yahoo.com  harshal@gmail.com  parag@gmail.com
# salary count             1.0                1.0         2.000000
#        mean            100.0              500.0       600.000000
#        std               NaN                NaN       565.685425
#        min             100.0              500.0       200.000000
#        25%             100.0              500.0       400.000000
#        50%             100.0              500.0       600.000000
#        75%             100.0              500.0       800.000000
#        max             100.0              500.0      1000.000000

# %%
df1
# Out:
#        name            mail_id  salary
# 0   harshal  harshal@gmail.com     500
# 1  abhishek     abhi@yahoo.com     100
# 2     riyan    parag@gmail.com    1000
# 3     parag    parag@gmail.com     200
