# %%
import pandas as pd

# %%
df = pd.read_csv('odb.csv')

# %%
df
# Out:
#       id                   Player       Span  Mat  Inns  NO   Runs    HS  \
# 0      0     SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*
# 1      1          V Kohli (INDIA)  2008-2021  254   245  39  12169   183
# 2      2     RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164
# 3      3        RG Sharma (INDIA)  2007-2021  227   220  32   9205   264
# 4      4  ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189
# ..   ...                      ...        ...  ...   ...  ..    ...   ...
# 114  114         SK Raina (INDIA)  2005-2018  226   194  35   5615  116*
# 115  115        H Masakadza (ZIM)  2001-2019  209   208   4   5658  178*
# 116  116       RB Richardson (WI)  1983-1996  224   217  30   6248   122
# 117  117         BB McCullum (NZ)  2002-2016  260   228  28   6083   166
# 118  118       Saleem Malik (PAK)  1982-1999  283   256  38   7170   102
#
#        Ave     BF     SR  100  50   0    4s   6s
# ...

# %%
df.sort_values(by=['Runs'], ascending=False).head()
# Out:
#     id                       Player       Span  Mat  Inns  NO   Runs    HS  \
# 0    0         SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*
# 8    8  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169
# 2    2         RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164
# 4    4      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189
# 15  15   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144
#
#       Ave     BF     SR  100  50   0    4s   6s
# 0   44.83  21368  86.23   49  96  20  2016  195
# 8   41.98  18048  78.86   25  93  15  1385   88
# 2   42.03  17046  80.39   30  82  20  1231  162
# 4   32.36  14725  91.20   28  68  34  1500  270
# 15  33.37  16020  78.96   19  77  28  1119   76

# %%
df.nlargest(10, 'Runs')
# Out:
#     id                       Player       Span  Mat  Inns  NO   Runs    HS  \
# 0    0         SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*
# 8    8  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169
# 2    2         RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164
# 4    4      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189
# 15  15   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144
# 1    1              V Kohli (INDIA)  2008-2021  254   245  39  12169   183
# 57  57    Inzamam-ul-Haq (Asia/PAK)  1991-2007  378   350  53  11739  137*
# 21  21       JH Kallis (Afr/ICC/SA)  1996-2014  328   314  53  11579   139
# 9    9      SC Ganguly (Asia/INDIA)  1992-2007  311   300  23  11363   183
# 39  39    R Dravid (Asia/ICC/INDIA)  1996-2011  344   318  40  10889   153
#
#       Ave     BF     SR  100  50   0    4s   6s
# 0   44.83  21368  86.23   49  96  20  2016  195
# ...

# %%
sr_gt_100 = df.query('SR  > 100')
sr_gt_100.sort_values(['SR'], ascending=False)
# Out:
#       id                        Player       Span  Mat  Inns  NO  Runs    HS  \
# 99    99               SO Hetmyer (WI)  2017-2021   47    44   3  1447   139
# 40    40             JM Bairstow (ENG)  2011-2021   89    81   8  3498  141*
# 58    58                  JJ Roy (ENG)  2015-2021   98    93   2  3658   180
# 106  106                DA Miller (SA)  2010-2021  137   118  35  3367   139
# 60    60              JC Buttler (ENG)  2012-2021  148   123  23  3872   150
# 6      6       AB de Villiers (Afr/SA)  2005-2018  228   218  39  9577   176
# 28    28     V Sehwag (Asia/ICC/INDIA)  1999-2013  251   245   9  8273   219
# 96    96  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398   369  27  8064   124
#
#        Ave    BF      SR  100  50   0    4s   6s
# 99   35.29  1360  106.39    5   4   2   111   52
# 40   47.91  3331  105.01   11  14   6   391   89
# 58   40.19  3410  107.27    9  20   9   428   73
# 106  40.56  3339  100.83    5  16   8   247   92
# ...
